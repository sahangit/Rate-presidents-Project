# %% [markdown]
# ## Visualization of president data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Growth mapped to reigns.csv')
pd.set_option('display.max_columns', None)

df.drop(columns = ['ID','Comment(HOS)','Comment(start year)','Political Experience'], inplace = True)
df['Age At Start'] = df['Year start'] - df['DOB']
df = df[df['Average'].notna()]
df.head()
# Out:
#      Country                                Name   DOB  Presidential term  \
# 1  Sri Lanka                Maithripala Sirisena  1951                  1
# 2  Sri Lanka                   Mahinda Rajapaksa  1945                  2
# 3  Sri Lanka                   Mahinda Rajapaksa  1945                  1
# 4  Sri Lanka  Chandrika Bandaranaike Kumaratunga  1945                  2
# 5  Sri Lanka  Chandrika Bandaranaike Kumaratunga  1945                  1
#
#    Year start  Year end Educational Background Professional Background  \
# 1        2015      2019                 School              Politician
# 2        2010      2014                    Law              Politician
# 3        2006      2009                    Law              Politician
# 4        2000      2005  Diploma(Phd followed)              Politician
# 5        1995      1999  Diploma(Phd followed)              Politician
#
#   Political Party                             University  \
# 1            SLFP                                   None
# 2            SLFP                            Law collage
# 3            SLFP                            Law collage
# 4            SLFP  Institut d'Etudes Politiques de Paris
# 5            SLFP  Institut d'Etudes Politiques de Paris
#
#               Birth Place Left Hand / Right Handed  Experience       Max  \
# 1      Gampaha, Sri Lanka                    Right          44  5.007683
# 2  Hambanthota, Sri Lanka                    Right          43  9.144572
# 3  Hambanthota, Sri Lanka                    Right          39  7.668292
# 4      Colombo, Sri Lanka                    Right          26  6.241748
# 5      Colombo, Sri Lanka                    Right          20  6.405400
#
#         Min   Average   Std Dev  Age At Start
# 1  2.283465  3.732474  1.060646            64
# 2  3.395733  6.784341  2.475964            65
# 3  3.538912  5.988530  1.777362            61
# 4 -1.545408  4.341063  2.997775            55
# 5  3.799967  4.940883  1.028109            50

# %% [markdown]
# ### Using pandas groupby function to tabulate aggregate data grouped by Categorical data.

# %%
df.groupby(['Country']).mean()
# Out:
#                         DOB  Presidential term  Year start     Year end  \
# Country
# China           1940.333333           1.500000      2005.5  2009.333333
# India           1937.600000           1.400000      2008.8  2012.800000
# Singapore       1946.500000           2.000000      2004.0  2007.666667
# Sri Lanka       1946.200000           1.400000      2005.2  2009.200000
# United Kingdom  1955.000000           1.500000      2007.5  2009.666667
# United States   1950.285714           1.428571      2005.0  2008.142857
#
#                 Experience        Max       Min   Average   Std Dev  \
# Country
# China            24.166667  10.400003  7.959846  9.075924  1.032548
# India            31.000000   7.568221  4.486467  6.235811  1.609937
# Singapore        24.000000   9.253605  2.033622  5.584072  3.160905
# Sri Lanka        34.400000   6.893539  2.294534  5.157458  1.867971
# United Kingdom   21.833333   2.688717  1.182743  1.965883  0.926582
# United States    20.428571   3.499042  0.933659  2.413946  1.142433
#
#                 Age At Start
# Country
# China              65.166667
# India              71.200000
# Singapore          57.500000
# Sri Lanka          59.000000
# United Kingdom     52.500000
# United States      54.714286

# %%
df.groupby('Professional Background').mean()
# Out:
#                                  DOB  Presidential term   Year start  \
# Professional Background
# Business                 1946.000000           1.333333  2007.666667
# Education                1932.000000           1.500000  2006.500000
# Engineering              1934.000000           1.500000  2000.500000
# Law                     2011.500000   41.000000  8.406432  3.467322  6.386435
# Masters                 2009.181818   28.909091  7.646957  2.251601  4.946171
# PhD                     2009.000000   27.000000  2.430553 -4.247822 -0.699474
# School                  2019.000000   44.000000  5.007683  2.283465  3.732474
#
#                          Std Dev  Age At Start
# Educational Background
# Bachelor’s              0.781242     60.111111
# DPhil                   1.739779     74.500000
# Degree                       NaN     55.000000
# Diploma(Phd followed)   2.012942     52.500000
# JD                      0.976412     49.500000
# LLD                     0.417166     62.500000
# Law                     2.126663     63.000000
# Masters                 2.562091     60.545455
# PhD                     3.358782     56.000000
# School                  1.060646     64.000000

# %%
df.groupby(['Left Hand / Right Handed','Country']).mean()
# Out:
#                                                  DOB  Presidential term  \
# Left Hand / Right Handed Country
# Left                     Singapore       1952.000000           2.000000
#                          United States   1953.500000           1.500000
# Right                    China           1940.333333           1.500000
#                          India           1937.600000           1.400000
#                          Singapore       1941.000000           2.000000
#                          Sri Lanka       1946.200000           1.400000
#                          United Kingdom  1955.000000           1.500000
#                          United States   1946.000000           1.333333
#
#                                           Year start     Year end  Experience  \
# Left Hand / Right Handed Country
# Left                     Singapore       2011.000000  2014.666667   27.000000
#                          United States   2003.000000  2006.000000   19.000000
# Right                    China           2005.500000  2009.333333   24.166667
#                          India           2008.800000  2012.800000   31.000000
#                          Singapore       1997.000000  2000.666667   21.000000
#                          Sri Lanka       2005.200000  2009.200000   34.400000
#                          United Kingdom  2007.500000  2009.666667   21.833333
#                          United States   2007.666667  2011.000000   22.333333
#
#                                                Max       Min   Average  \
# Left Hand / Right Handed Country
# Left                     Singapore        8.400038  1.280938  4.786321
#                          United States    3.563466  1.478213  2.736820
# Right                    China           10.400003  7.959846  9.075924
#                          India            7.568221  4.486467  6.235811
#                          Singapore       10.107171  2.786307  6.381823
#                          Sri Lanka        6.893539  2.294534  5.157458
#                          United Kingdom   2.688717  1.182743  1.965883
#                          United States    3.413144  0.207587  1.983447
#
#                                           Std Dev  Age At Start
# Left Hand / Right Handed Country
# Left                     Singapore       2.886788     59.000000
#                          United States   0.976412     49.500000
# Right                    China           1.032548     65.166667
#                          India           1.609937     71.200000
#                          Singapore       3.435022     56.000000
#                          Sri Lanka       1.867971     59.000000
#                          United Kingdom  0.926582     52.500000
#                          United States   1.363795     61.666667

# %% [markdown]
# ### Using plots to visualize data

# %%
# Distribution of ages when starting presidency

df["Age At Start"].plot.hist()
plt.show()

# %%
series_country = df['Country'].unique()
countries = len(series_country)

for country in range(countries):
    select = df.loc[df['Country']==series_country[country]]
    x = select['Age At Start'].tolist()
    y = select['Average'].tolist()
    
    plt.subplot(2, 3, country+1)
    plt.tight_layout()
    plt.scatter(x,y)
    plt.title(series_country[country])

plt.suptitle("Growth vs Age")
plt.tight_layout()
plt.show()

# %%
# For all data
    
x = np.array(df['Age At Start'].tolist())
y = np.array(df['Average'].tolist())

plt.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

plt.plot(x, m*x + b)
 
plt.show()

# %%
# it seems like age of the head of state is related with countires growth
# furthur analysis is needed using categorical data
